# %% [markdown]
# # NLP model to match product description to the right product HScode
# This model all about matching product descriptions to the correct Harmonized System(HS) code.

# %% [markdown]
# # Importing Necessary Libraries

# %%
import re
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# %% [markdown]
# # Importing the Dataset

# %%
data=pd.read_csv('Data\product_hs_code_data.csv')
data.head()
# Out:
#                               description  hs_code
# 0      blue watch, size small, battery AA   910211
# 1     blue bike, size small, model hybrid   871190
# 2  blue clothes, size S, fabric polyester   620293
# 3       blue clothes, size M, fabric wool   620293
# 4          red car model 2023, size truck   870320

# %% [markdown]
# # Data Pre-Processing

# %%
from nltk.stem import WordNetLemmatizer
wordnet=WordNetLemmatizer()
corpus_lemmatization=[]

for i in range(len(data)):
    review=re.sub('[^a-zA-Z]',' ',data['description'][i])
    #review=review.lower()
    review=review.split()

    review=[wordnet.lemmatize(word) for word in review if not word in set (stopwords.words('english'))]
    review=' '.join(review)
    corpus_lemmatization.append(review)

# %%
print(corpus_lemmatization)
# Out:
# ['blue watch size small battery AA', 'blue bike size small model hybrid', 'blue clothes size S fabric polyester', 'blue clothes size M fabric wool', 'red car model size truck', 'black watch size medium battery rechargeable', 'blue bike size medium model road', 'blue watch size small battery AAA', 'silver watch size medium battery rechargeable', 'red bike size large model road', 'black bike size medium model road', 'blue watch size medium battery rechargeable', 'red car model size SUV', 'blue car model size truck', 'black mobile size inch battery mAh compatibility G', 'red mobile size inch battery mAh compatibility G', 'green clothes size XL fabric cotton', 'white mobile size inch battery mAh compatibility G', 'green clothes size L fabric polyester', 'green clothes size M fabric wool', 'red mobile size inch battery mAh compatibility G', 'black clothes size S fabric wool', 'red bike size large model mountain', 'green bike size medium model hybrid', 'green clothes size L fabric cotton', 'black bike size small model road', 'blue watch size small battery AAA', 'green bike size large model mountain', 'gold watch size large battery AA', 'red car model size SUV', 'black car model size truck', 'silver watch size large battery AAA', 'red clothes size L fabric polyester', 'green clothes size L fabric cotton', 'gold watch size small battery AA', 'red bike size large model hybrid', 'black mobile size inch battery mAh compatibility G', 'silver watch size medium battery AA', 'white mobile size inch battery mAh compatibility G', 'blue clothes size XL fabric cotton', 'green clothes size M fabric wool', 'gold watch size medium battery AAA', 'gold watch size large battery AA', 'black bike size medium model road', 'white car model size SUV', 'blue mobile size inch battery mAh compatibility G', 'green bike size large model mountain', 'blue watch size medium battery AAA', 'white mobile size inch battery mAh compatibility G', 'black car model size SUV', 'black clothes size S fabric polyester', 'blue bike size small model mountain', 'blue car model size SUV', 'white mobile size inch battery mAh compatibility G', 'blue mobile size inch battery mAh compatibility G', 'black mobile size inch battery mAh compatibility G', 'silver watch size small battery rechargeable', 'red bike size medium model road', 'white car model size truck', 'black mobile size inch battery mAh compatibility G', 'green clothes size XL fabric cotton', 'black car model size truck', 'black bike size large model mountain', 'black car model size sedan', 'green bike size medium model road', 'blue car model size sedan', 'blue mobile size inch battery mAh compatibility G', 'green clothes size M fabric polyester', 'blue mobile size inch battery mAh compatibility G', 'blue watch size small battery AA', 'white car model size sedan', 'green bike size medium model hybrid', 'green bike size large model hybrid', 'green bike size small model road', 'white car model size truck', 'black mobile size inch battery mAh compatibility G', 'black clothes size S fabric polyester', 'black bike size medium model road', 'black watch size large battery AA', 'black mobile size inch battery mAh compatibility G', 'red mobile size inch battery mAh compatibility G', 'black watch size small battery rechargeable', 'black car model size SUV', 'green bike size medium model hybrid', 'blue bike size medium model road', 'white car model size compact', 'black clothes size S fabric wool', 'blue clothes size S fabric polyester', 'red bike size large model mountain', 'blue bike size large model road', 'white car model size truck', 'green bike size large model mountain', 'black car model size sedan', 'black bike size small model mountain', 'white car model size compact', 'black watch size small battery AAA', 'black clothes size L fabric polyester', 'green clothes size S fabric wool', 'black bike size small model road', 'black bike size medium model hybrid', 'gold watch size medium battery AAA', 'black mobile size inch battery m ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer()
X = cv.fit_transform(corpus_lemmatization).toarray()

# %%
y=data.hs_code

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB().fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
c_m=confusion_matrix(y_test,y_pred)
print("confusion matrix:\n", c_m)

from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy score:\n",accuracy)
# Out:
# confusion matrix:
#  [[123   0   0   0   0]
#  [  0 113   0   0   0]
#  [  0   0 123   0   0]
#  [  0   0   0 123   0]
#  [  0   0   0   0 118]]
# Accuracy score:
#  1.0

# %%
import joblib

# Save the trained model
joblib.dump(model, 'multinomial_nb_model.pkl')

# Save the fitted TfidfVectorizer
joblib.dump(cv, 'tfidf_vectorizer.pkl')
# Out:
# ['tfidf_vectorizer.pkl']

# %%
# Load the trained model and vectorizer
loaded_model = joblib.load('multinomial_nb_model.pkl')
loaded_vectorizer = joblib.load('tfidf_vectorizer.pkl')

# %%
new_sentence = "i need a device to check my time which is small and have good battery"


new_sentence = re.sub('[^a-zA-Z]', ' ', new_sentence)
new_sentence = new_sentence.split()

wordnet = WordNetLemmatizer()
new_sentence = [wordnet.lemmatize(word) for word in new_sentence if not word in set(stopwords.words('english'))]
new_sentence = ' '.join(new_sentence)

new_sentence_transformed = loaded_vectorizer.transform([new_sentence]).toarray()

prediction = loaded_model.predict(new_sentence_transformed)

print("Predicted HS code:", prediction[0])
# Out:
# Predicted HS code: 910211
