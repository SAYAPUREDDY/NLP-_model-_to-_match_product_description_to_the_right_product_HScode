# %% [markdown]
# # NLP model to match product description to the right product HScode
# This model all about matching product descriptions to the correct Harmonized System(HS) code.

# %% [markdown]
# # Importing Necessary Libraries

# %%
import re
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # Importing the Dataset
# - The dataset consists of the various product descriptions of the car,bike and watch.
# - It is the custom created dataset created for this task.

# %%
data=pd.read_csv('Data\data.csv')
print(data)
# Out:
#                                    product description  Hscode
# 0    A sleek black phone featuring a 6.5-inch displ...  851712
# 1    Compact yet powerful, this white mobile boasts...  851712
# 2    Experience lightning-fast performance with thi...  851712
# 3    Experience lightning-fast performance with thi...  851712
# 4    Designed for the on-the-go professional, this ...  851712
# ..                                                 ...     ...
# 895  This stylish red cruiser bike includes wide ti...  871190
# 896  With a modern white design and a 27-speed gear...  871190
# 897  The sleek black folding bike features a compac...  871190
# 898  This vibrant blue road bike includes a lightwe...  871190
# 899  With a stylish green hybrid bike and front sus...  871190
#
# [900 rows x 2 columns]

# %% [markdown]
# # Data Pre-Processing
# - Removing unnecessary characters
# - lowering the data
# - removing the stopwords
# - creating a corpus bby using lemmatization

# %%
from nltk.stem import WordNetLemmatizer
wordnet=WordNetLemmatizer()
corpus_lemmatization=[]

for i in range(len(data)):
    review=re.sub('[^a-zA-Z]',' ',data['product description'][i])
    review=review.lower()
    review=review.split()

    review=[wordnet.lemmatize(word) for word in review if not word in set (stopwords.words('english'))]
    review=' '.join(review)
    corpus_lemmatization.append(review)

# %%
print(corpus_lemmatization)
# Out:
# ['sleek black phone featuring inch display powerful mah battery perfect gaming binge watching favorite show', 'compact yet powerful white mobile boast g connectivity crystal clear inch screen ideal video call social medium', 'experience lightning fast performance blue inch mobile equipped quad camera system fast charging capability', 'experience lightning fast performance blue inch mobile equipped quad camera system fast charging capability', 'designed go professional green mobile offer dual sim support inch display face recognition added security', 'black mobile phone inch display fingerprint sensor perfect capturing life moment quad camera setup', 'stylish white phone mah battery ideal work play featuring wireless charging water resistant design', 'redefine mobile experience blue device featuring high resolution screen fast charging seamless multitasking capability', 'ultimate mobile streaming enthusiast red inch phone come mah battery stereo speaker immersive audio', 'rugged mobile designed outdoor adventure green inch phone water resistant equipped mah battery', 'sophisticated gold watch solar powered battery heart rate monitor perfect tracking fitness goal style', 'sleek black smartwatch feature gps tracking bluetooth connectivity making ideal staying connected workout', 'designed modern adventurer silver watch offer large display waterproof design customizable watch face', 'stay top health rose gold fitness watch featuring sleep monitor long lasting battery continuous tracking', 'stylish blue watch built microphone music control perfect hand free call managing playlist go', 'black sport watch equipped rechargeable battery heart rate monitor ideal athlete fitness enthusiast', 'classic silver watch gps tracking bluetooth perfect casual wear outdoor activity', 'gold luxury watch offer solar powered battery customizable face blending style cutting edge technology', 'perfect companion daily run black watch feature fitness tracking music control water resistance', 'designed busy professional silver smartwatch offer seamless connectivity large display durable waterproof build', 'lightweight red mountain bike durable tire disc brake perfect conquering rugged trail steep hill', 'sleek black road bike feature high performance gear system adjustable seat ideal long distance cycling', 'built speed green hybrid bike offer foldable design electric assist making perfect urban commuting', 'blue electric bike led light shock absorber designed eco friendly travel weekend adventure', 'versatile yellow bike combine lightweight frame disc brake durable tire ideal city ride mountain trail', 'experience thrill road cycling black mountain bike featuring robust frame electric assist extra power', 'compact foldable red bike high performance gear led light perfect navigating city street', 'large blue bike offer smooth ride shock absorber adjustable seat designed fitness exercise enthusiast', 'electric green bike powerful motor durable tire perfect daily commute reducing carbon footprint', 'built endurance black hybrid bike feature lightweight frame disc brake foldable design easy storage', 'sleek black mobile feature inch screen mah battery ideal immersive gaming watching movie go', 'enjoy high speed g connectivity white phone equipped inch display ai enhanced camera stunning photo', 'green mobile offer inch screen long lasting mah battery perfect streaming video multitasking seamlessly', 'capture every moment blue phone quad camera setup fast charging mah battery ideal social medium enthusiast', 'stylish red mobile includes inch display powerful mah battery designed professional need reliable performance', 'inch screen dual sim support black mobile perfect travel staying connected work family', 'white phone feature high resolution inch display fingerprint sensor ideal work entertainment', 'enjoy ultimate mobile experience blue phone featuring mah battery ai powered camera high quality photo', 'green mobile offer g connectivity inch screen perfect ...

# %% [markdown]
# # TF-IDF
# - to retrieve the information.
# - words are tranformed into vectors by text vectorization process.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer()
X = cv.fit_transform(corpus_lemmatization).toarray()

# %%
y=data.Hscode

# %% [markdown]
# # Splitting the data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %% [markdown]
# # Multinomial NaiveBayes model

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB().fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
c_m=confusion_matrix(y_test,y_pred)
print("confusion matrix:\n", c_m)

from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy score:\n",accuracy)
# Out:
# confusion matrix:
#  [[59  0  0]
#  [ 0 64  0]
#  [ 0  0 57]]
# Accuracy score:
#  1.0

# %% [markdown]
# # Saving the Models

# %%
import joblib

# Save the trained model
joblib.dump(model, 'multinomial_nb_model.pkl')

# Save the fitted TfidfVectorizer
joblib.dump(cv, 'tfidf_vectorizer.pkl')

# %%
loaded_model = joblib.load('multinomial_nb_model.pkl')
loaded_vectorizer = joblib.load('tfidf_vectorizer.pkl')

# %% [markdown]
# # Test the model with the product descriptions
# The model is tested with the real amazon product descriptions and the predictions are correct and satisfying.

# %%
new_sentence = "Specifications: 123 kms range in single charge; 63 kmph top speed (Unlock 3 ride modes with TecPac: 2 Forward - Eco and Sports and 1 Reverse)"


new_sentence = re.sub('[^a-zA-Z]', ' ', new_sentence)
new_sentence = new_sentence.split()

wordnet = WordNetLemmatizer()
new_sentence = [wordnet.lemmatize(word) for word in new_sentence if not word in set(stopwords.words('english'))]
new_sentence = ' '.join(new_sentence)

new_sentence_transformed = loaded_vectorizer.transform([new_sentence]).toarray()

prediction = loaded_model.predict(new_sentence_transformed)
#print(prediction)
prediction_prob=loaded_model.predict_proba(new_sentence_transformed)
#print(prediction_prob)
prediction_prob = prediction_prob.max()
#print(prediction_prob)

if prediction_prob <= 0.5:
    print("Cannot find the product you are searching for,the similar product that has similar features to your description is", prediction[0])
else:
    print(prediction[0])
# Out:
# 871190
